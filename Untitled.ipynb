# %%
import pandas as pd

# %%
file = 'C:/Users/admin/Desktop/TestFolders/Hela_tol_ - Copy/combined/txt/proteinGroups.txt'

# %%
df = pd.read_csv(file, sep='\t')

# %%
df['Majority protein IDs'].nunique()
# Out:
# 3548

# %%
df
# Out:
#                                             Protein IDs  \
# 0     A0A024QZP7;P06493;E5RIU6;A0A087WZZ9;G3V317;K7ELV5
# 1     A0A2R8YD12;A0A024QZX5;A0A087X1N8;P35237;A0A2R8...
# 2     A0A024R4E5;Q00341;H0Y394;H7C0A4;C9J5E5;C9JIZ1;...
# 3               A0A087WZA9;A0A024R4K9;A0A087X266;Q9BXJ8
# 4     C9JC03;A0A024R571;Q9H4M9;C9JDQ8;C9J2Z4;C9JIJ3;...
# ...                                                 ...
# 3543                                        REV__Q9NQ87
# 3544                                        REV__Q9NRF8
# 3545                                        REV__Q9P2T0
# 3546                                        REV__Q9Y2U8
# 3547                                             X6R960
#
#                          Majority protein IDs        Peptide counts (all)  \
# 0         A0A024QZP7;P06493;E5RIU6;A0A087WZZ9                 5;5;4;4;1;1
# 1     A0A2R8YD12;A0A024QZX5;A0A087X1N8;P35237                   4;4;4;4;1
# ...
