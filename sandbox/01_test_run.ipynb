# %% [markdown]
# # AlphaPept Test Runs and Visualization Examples
#
# This notebooks is intended to show how a IRT File can be processed.

# %% [markdown]
# ## Download Test Data

# %%
import os
try:
    import wget
except ModuleNotFoundError:
    # !pip install wget
    import wget
    
FILE_DICT = {}
FILE_DICT['thermo_IRT.raw'] = 'https://datashare.biochem.mpg.de/s/GpXsATZtMwgQoQt/download'
FILE_DICT['IRT_fasta.fasta'] = 'https://datashare.biochem.mpg.de/s/p8Qu3KolzbSiCHH/download'

tmp_folder = os.path.join(os.getcwd(),'/temp_test_run')

if not os.path.isdir(tmp_folder):
    os.mkdir(tmp_folder)
    
for file in FILE_DICT:
    target = os.path.join(tmp_folder, file)
    if not os.path.isfile(target):
        wget.download(FILE_DICT[file], target)

# %% [markdown]
# ## Test Run

# %%
from alphapept.settings import load_settings
from alphapept.paths import DEFAULT_SETTINGS_PATH

settings = load_settings(DEFAULT_SETTINGS_PATH)

settings['experiment']['file_paths'] =  [os.path.join(tmp_folder, 'thermo_IRT.raw')]
settings['experiment']['fasta_paths'] = [os.path.join(tmp_folder, 'IRT_fasta.fasta')]
    
import alphapept.interface

settings_ = alphapept.interface.run_complete_workflow(settings)
# Out:
# 2022-10-24 19:14:55> Logging to C:\Users\admin\alphapept\logs\log_20221024191455.txt.
# 2022-10-24 19:14:55> Code location f:\projects\alphapept\alphapept
# 2022-10-24 19:14:55> Python location C:\Users\admin\.conda\envs\alphapept_stable\python.exe
# 2022-10-24 19:14:55> Platform information:
# 2022-10-24 19:14:55> system     - Windows
# 2022-10-24 19:14:55> release    - 10
# 2022-10-24 19:14:55> version    - 10.0.19044
# 2022-10-24 19:14:55> machine    - AMD64
# 2022-10-24 19:14:55> processor  - Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# 2022-10-24 19:14:55> cpu count  - 24
# 2022-10-24 19:14:55> ram memory - 120.7/127.7 Gb (available/total)
# 2022-10-24 19:14:55> processor  - Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# 2022-10-24 19:14:55> Python information:
# 2022-10-24 19:14:55> SQLAlchemy                    - 1.4.39
# 2022-10-24 19:14:55> alphapept                     - 0.4.9
# 2022-10-24 19:14:55> biopython                     - 1.79
# 2022-10-24 19:14:55> bumpversion                   -
# 2022-10-24 19:14:55> bumpversion>                  -
# 2022-10-24 19:14:55> click                         - 8.1.3
# 2022-10-24 19:14:55> click>                        -
# 2022-10-24 19:14:55> fastcore                      - 1.5.26
# 2022-10-24 19:14:55> h5py                          - 3.7.0
# 2022-10-24 19:14:55> jupyter                       -
# 2022-10-24 19:14:55> jupyter>                      -
# 2022-10-24 19:14:55> jupyter_contrib_nbextensions  -
# 2022-10-24 19:14:55> jupyter_contrib_nbextensions> -
# 2022-10-24 19:14:55> matplotlib                    - 3.6.1
# 2022-10-24 19:14:55> nbdev                         -
# 2022-10-24 19:14:55> nbdev>                        -
# 2022-10-24 19:14:55> networkx                      - 2.8.6
# 2022-10-24 19:14:55> numba                         - 0.55.2
# 2022-10-24 19:14:55> numpy                         - 1.20.3
# 2022-10-24 19:14:55> pandas                        - 1.4.3
# 2022-10-24 19:14:55> plotly_express                - 0.4.1
# 2022-10-24 19:14:55> psutil                        - 5.9.1
# 2022-10-24 19:14:55> pyinstaller                   -
# 2022-10-24 19:14:55> pyteomics                     - 4.5.5
# 2022-10-24 19:14:55> python                        - 3.8.13
# 2022-10-24 19:14:55> pythonnet                     - 2.5.2
# 2022-10-24 19:14:55> pywin32                       - 225
# 2022-10-24 19:14:55> pyyaml                        - 6.0
# 2022-10-24 19:14:55> scikit-learn                  - 1.1.2
# 2022-10-24 19:14:55> scipy                         - 1.8.1
# 2022-10-24 19:14:55> streamlit                     - 1.13.0
# 2022-10-24 19:14:55> streamlit-aggrid              - 0.2.3.post2
# 2022-10-24 19:14:55> streamlit>                    -
# 2022-10-24 19:14:55> tables                        - 3.6.1
# 2022-10-24 19:14:55> tqdm                          - 4.64.0
# 2022-10-24 19:14:55> twine                         -
# 2022-10-24 19:14:55> twine>                        -
# 2022-10-24 19:14:55> watchdog                      - 2.1.9
# 2022-10-24 19:14:55> wget                          - 3.2
# 2022-10-24 19:14:55>
# 2022-10-24 19:14:55> Check for settings not completely implemented yet.
# 2022-10-24 19:14:55> Size check:
# 2022-10-24 19:14:55> Size of job (raw files) 0.07 Gb
# 2022-10-24 19:14:55> Required disk space for F: - 0.07 Gb, Available 369.24 Gb OK.
# 2022-10-24 19:14:55>
# 2022-10-24 19:14:55> Workflow Settings:
# 2022-10-24 19:14:55> align              - False
# 2022-10-24 19:14:55> continue_runs      - False
# 2022-10-24 19:14:55> create_database    - True
# 2022-10-24 19:14:55> find_features      - True
# 2022-10-24 19:14:55> import_raw_data    - True
# 2022-10-24 19:14:55> lfq_quantification - True
# 2022-10-24 19:14:55> match              - False
# 2022-10-24 19:14:55> recalibrate_data   - True
# 2022-10-24 19:14:55> search_data        - True
# 2022-10-24 19:14:55>
# 2022-10-24 19:14:55> Checking if files exist.
# 2022-10-24 19:14:55> FASTA Files have a total size of 0.000 Mb
# 2022-10-24 19:14:55> Results path was not set. Setting to F:\temp_test_run\results.hdf
# 2022-10-24 19:14:55> Shortnames not set. Setting to filename.
# 2022-10-24 19:14:55> Sample group not set. Setting to shortname.
# 2022-10-24 19:14:55> Fraction not set. Setting to 1.
# 2022-10-24 19:14:55> No database path set and save_db option checked. Using default path F:\temp_test_run\database.hdf
# 2022-10-24 19:14:55> Deleted F:/temp_test_run\thermo_IRT.ms_data.hdf
# 2022-10-24 19:14:55> Workflow has 11 steps
# 2022-10-24 19:14:55> ==== create_database ====
# 2022-10-24 19:14:55> Database path set and exists. Using F:\temp_test_run\database.hdf as database.
# 2022-10-24 19:14:55> ==== import_raw_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:14:55> Processing 1 files for step raw_conversion
# 2022-10-24 19:14:55> File F:/temp_test_run\thermo_IRT has extension .raw - converting from Thermo.
# 2022-10-24 19:15:00> File conversion complete. Extracted 2,603 precursors.
# 2022-10-24 19:15:00> File conversion of file F:/temp_test_run\thermo_IRT.raw complete.
#   0%|                                                                                            | 0/1 [00:04<?, ?it/s]
# 2022-10-24 19:15:00> ==== feature_finding ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:15:04> Processing 1 files for step find_features
# 2022-10-24 19:15:04> No *.hdf file with features found for F:/temp_test_run\thermo_IRT.ms_data.hdf. Adding to feature finding list.
# 2022-10-24 19:15:04> Feature finding on F:/temp_test_run\thermo_IRT.raw
# 2022-10-24 19:15:04> Hill extraction with centroid_tol 8 and max_gap 2
# 2022-10-24 19:15:08> Number of hills 45,516, len = 20.18
# 2022-10-24 19:15:08> Repeating hill extraction with centroid_tol 5.10
# 2022-10-24 19:15:09> Number of hills 52,919, len = 21.29
# 2022-10-24 19:15:11> After duplicate removal of hills 43,950
# 2022-10-24 19:15:18> After split hill_ptrs 61,693
# 2022-10-24 19:15:19> After filter hill_ptrs 60,175
# 2022-10-24 19:15:30> Extracting hill stats complete
# 2022-10-24 19:15:33> Found 7,045 pre isotope patterns.
# 2022-10-24 19:15:51> Extracted 6,428 isotope patterns.
# 2022-10-24 19:16:00> Report complete.
# 2022-10-24 19:16:00> Matching features to query data.
# 2022-10-24 19:16:00> Saving feature table.
# 2022-10-24 19:16:00> Feature table saved to F:/temp_test_run\thermo_IRT.ms_data.hdf
# 2022-10-24 19:16:00> Saving features.
# 2022-10-24 19:16:00> Feature finding of file F:/temp_test_run\thermo_IRT.raw complete.
#   0%|                                                                                            | 0/1 [00:56<?, ?it/s]
# 2022-10-24 19:16:00> ==== search_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:00> Starting first search.
# 2022-10-24 19:16:00> Processing 1 files for step search_db
# 2022-10-24 19:16:00> Calibrating fragments
# 2022-10-24 19:16:06> Performing search on 2,969 query and 5,045,760 db entries with frag_tol = 50.00 and prec_tol = 20.00.
# 2022-10-24 19:16:08> Found 111 psms.
# 2022-10-24 19:16:08> Extracting columns for scoring.
# 2022-10-24 19:16:16> Extracted columns from 111 spectra.
# 2022-10-24 19:16:16> Saving first_search results to F:/temp_test_run\thermo_IRT.ms_data.hdf
# 2022-10-24 19:16:17> Search of file F:/temp_test_run\thermo_IRT.raw complete.
# 2022-10-24 19:16:31> First search complete.
#   0%|                                                                                            | 0/1 [00:31<?, ?it/s]
# 2022-10-24 19:16:31> ==== recalibrate_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:31> Processing 1 files for step calibrate_hdf
# 2022-10-24 19:16:31> Recalibrating file F:/temp_test_run\thermo_IRT.raw.
# 2022-10-24 19:16:31> Scoring using generic score
# 2022-10-24 19:16:32> 8 target (0 decoy) of 59 PSMs. FDR 0.000000 for a cutoff of 10.81 (set FDR was 0.01).
# 2022-10-24 19:16:32> Precursor mass calibration for file F:/temp_test_run\thermo_IRT.raw.
# 2022-10-24 19:16:32> Not enough data points present. Skipping recalibration.
# 2022-10-24 19:16:32> Precursor calibration of file F:/temp_test_run\thermo_IRT.ms_data.hdf complete.
# 2022-10-24 19:16:32> Starting fragment calibration.
# 2022-10-24 19:16:32> Calibrating fragments with neighbors
# 2022-10-24 19:16:32> Scoring using generic score
# 2022-10-24 19:16:32> 8 target (0 decoy) of 59 PSMs. FDR 0.000000 for a cutoff of 10.81 (set FDR was 0.01).
# 2022-10-24 19:16:32> Minimum hits for fragments before score 7.01.
# 2022-10-24 19:16:32> Minimum hits for fragments after score 7.31.
# 2022-10-24 19:16:32> Not enough datapoints 74 for fragment calibration. Minimum is set to 400. Skipping fragment calibration.
# 2022-10-24 19:16:32> Fragment calibration of file F:/temp_test_run\thermo_IRT.ms_data.hdf complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:32> ==== search_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:32> Starting second search with DB.
# 2022-10-24 19:16:32> Processing 1 files for step search_db
# 2022-10-24 19:16:32> Found calibrated prec_tol with value 8.21
# 2022-10-24 19:16:32> 'Dataset estimated_max_fragment_ppm does not exist for group / of <HDF_File F:\\temp_test_run\\thermo_IRT.ms_data.hdf>.'
# 2022-10-24 19:16:32> Performing search on 2,969 query and 5,045,760 db entries with frag_tol = 50.00 and prec_tol = 8.21.
# 2022-10-24 19:16:32> Found 51 psms.
# 2022-10-24 19:16:32> Extracting columns for scoring.
# 2022-10-24 19:16:36> Extracted columns from 51 spectra.
# 2022-10-24 19:16:36> Saving second_search results to F:/temp_test_run\thermo_IRT.ms_data.hdf
# 2022-10-24 19:16:36> Search of file F:/temp_test_run\thermo_IRT.raw complete.
# 2022-10-24 19:16:49> Second search complete.
#   0%|                                                                                            | 0/1 [00:16<?, ?it/s]
# 2022-10-24 19:16:49> ==== score ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:49> Processing 1 files for step score_hdf
# 2022-10-24 19:16:49> Calling score_hdf
# 2022-10-24 19:16:49> Found second search psms for scoring.
# 2022-10-24 19:16:50> 5 target (0 decoy) of 33 PSMs. FDR 0.000000 for a cutoff of 23.74 (set FDR was 0.1).
# 2022-10-24 19:16:50> ML failed. Defaulting to x_tandem score
# 2022-10-24 19:16:50> There are fewer high scoring targets or decoys than required by 'min_train'.
# 2022-10-24 19:16:50> Converting x_tandem score to probabilities
# 2022-10-24 19:16:50> 5 target (0 decoy) of 35 PSMs. FDR 0.000000 for a cutoff of 0.90 (set FDR was 0.01).
# 2022-10-24 19:16:50> Saving identifications to ms_data file.
# 2022-10-24 19:16:50> Saving identifications to ms_data file complete.
# 2022-10-24 19:16:50> Saving identifications to csv file complete.
# 2022-10-24 19:16:50> Filter df with custom score
# 2022-10-24 19:16:50> Global FDR on precursor
# 2022-10-24 19:16:50> 5 target (0 decoy) of 33 PSMs. FDR 0.000000 for a cutoff of 0.90 (set FDR was 0.01).
# 2022-10-24 19:16:50> Global FDR cutoff at 0.902.
# 2022-10-24 19:16:50> FDR on peptides complete. For 0.01 FDR found 5 targets and 0 decoys.
# 2022-10-24 19:16:50> Extracting fragment_ions
# 2022-10-24 19:16:50> Extracting fragment_ions complete.
# 2022-10-24 19:16:50> Exporting peptide_fdr on F:/temp_test_run\thermo_IRT.raw.
# 2022-10-24 19:16:50> Scoring of files F:/temp_test_run\thermo_IRT.raw complete.
#   0%|                                                                                            | 0/1 [00:01<?, ?it/s]
# 2022-10-24 19:16:50> ==== isobaric_labeling ====
# 2022-10-24 19:16:50> ==== protein_grouping ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:50> Fasta dict with length 20,365, Pept dict with length 5,045,764
# 2022-10-24 19:16:50> Extracting protein groups.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:51> A total of 5 unique and 0 shared peptides.
# 2022-10-24 19:16:51> A total of 0 ambigious proteins
# 2022-10-24 19:16:51> A total of 0 unique and 0 shared peptides.
# 2022-10-24 19:16:51> A total of 0 ambigious proteins
# 2022-10-24 19:16:51> Global FDR on protein_group
# 2022-10-24 19:16:51> Last q_value 0.000 of dataset is smaller than fdr_level 0.010
# 2022-10-24 19:16:51> 4 target (0 decoy) of 4 PSMs. FDR 0.000000 for a cutoff of 0.90 (set FDR was 0.01).
# 2022-10-24 19:16:51> Global FDR cutoff at 0.902.
# 2022-10-24 19:16:51> FDR on proteins complete. For 0.01 FDR found 5 targets and 0 decoys. A total of 4 proteins found.
# 2022-10-24 19:16:51> Saving complete.
# 2022-10-24 19:16:51> Protein groups complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:51> ==== quantification ====
# 2022-10-24 19:16:51> Reading protein_fdr for quantification.
# 2022-10-24 19:16:51> Saving protein_groups after delayed normalization to combined_protein_fdr_dn
# 2022-10-24 19:16:51> Complete.
# 2022-10-24 19:16:51> Starting profile extraction.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-10-24 19:16:51> LFQ complete.
# 2022-10-24 19:16:51> Extracting protein_summary
# 2022-10-24 19:16:51> Saved protein_summary of length 4 saved to F:\temp_test_run\results_protein_summary.csv
# 2022-10-24 19:16:51> Updating protein_fdr.
# 2022-10-24 19:16:51> Exporting as csv.
# 2022-10-24 19:16:51> Saved df of length 5 saved to F:\temp_test_run\results
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.41it/s]
# 2022-10-24 19:16:51> ==== export ====
# 2022-10-24 19:16:51> Settings saved to F:\temp_test_run\results.yaml
# 2022-10-24 19:16:51> Analysis complete.

# %% [markdown]
# ## Basic file access
#
# Files can be read via the alphapept.io class and displayed as pandas dataframe

# %%
import alphapept.io

_ = settings['experiment']['file_paths'][0]
base, ext = os.path.splitext(_)

ms_file = alphapept.io.MS_Data_File(base+'.ms_data.hdf')

print(ms_file.read())

df = ms_file.read(dataset_name='peptide_fdr')

df.head()
# Out:
# ['Raw', 'corrected_fragment_mzs', 'feature_cluster_mapping', 'feature_table', 'feature_table_idx', 'features', 'first_search', 'fragment_ions', 'identifications', 'peptide_fdr', 'second_search']
#    charge   db_idx  decoy  decoys_cum   delta_m  delta_m_ppm  delta_m_ppm_abs  \
# 0     2.0   612098  False           0 -0.002094    -6.232794         6.232794
# 1     2.0  1221756  False           0  0.007446    16.766964        16.766964
# 2     2.0  1960963  False           0 -0.021495   -38.164696        38.164696
# 3     2.0  2131880  False           0 -0.023571   -47.653160        47.653160
# 4     2.0  2169566  False           0 -0.016631   -28.506237        28.506237
#
#    fdr  feature_idx  fragment_ion_idx  ... scan_no     score  score_precursor  \
# 0  0.0         1582                48  ...     650  0.901961         0.901961
# 1  0.0         1988               144  ...    2636  0.921569         0.921569
# 2  0.0          201               360  ...    3318  0.980392         0.980392
# 3  0.0          624               645  ...    3529  1.000000         1.000000
# 4  0.0         2421               658  ...    3469  0.960784         0.960784
#
#    score_rank         sequence  sequence_naked  target  target_cum  \
# 0           1      GLSATVTGGQK     GLSATVTGGQK    True           5
# 1           1     FLASVSTVLTSK    FLASVSTVLTSK    True           4
# 2           1   TRFLEGLSEAVTTK  TRFLEGLSEAVTTK    True           2
# 3           1    DVFLGMFLYEYAR   DVFLGMFLYEYAR    True           1
# 4           1  DVFLGoxMFLYEYAR   DVFLGMFLYEYAR    True           3
#
#    target_precursor   x_tandem
# 0              True  23.735165
# 1              True  23.789697
# 2              True  25.144608
# 3              True  29.848937
# 4              True  24.628600
#
# [5 rows x 62 columns]

# %% [markdown]
# ## MS2 Spectrum
#
# Visualize PSMS

# %%
try:
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    # !pip install matplotlib
    import matplotlib.pyplot as plt

def plot_psms(precursor, ms_file):

    df = ms_file.read(dataset_name='peptide_fdr')
    
    ion_dict = {}
    ion_dict[0] = ''
    ion_dict[1] = '-H20'
    ion_dict[2] = '-NH3'

    spectrum = df[df['precursor'] == precursor].iloc[0]
    start = spectrum['fragment_ion_idx']
    end = spectrum['n_fragments_matched'] + start

    query_data = ms_file.read_DDA_query_data()
    ions = ms_file.read(dataset_name="fragment_ions")

    ion = [('b'+str(int(_))).replace('b-','y') for _ in ions.iloc[start:end]['ion_index']]
    losses = [ion_dict[int(_)] for _ in ions.iloc[start:end]['fragment_ion_type']]
    ion = [a+b for a,b in zip(ion, losses)]
    ints = ions.iloc[start:end]['fragment_ion_int'].astype('int').values
    masses = ions.iloc[start:end]['fragment_ion_mass'].astype('float').values
    ion_type = ions.iloc[start:end]['fragment_ion_type'].abs().values

    query_idx = spectrum['raw_idx']

    query_indices = query_data["indices_ms2"]
    query_charges = query_data['charge2']
    query_frags = query_data['mass_list_ms2']
    query_ints = query_data['int_list_ms2']

    query_idx_start = query_indices[query_idx]
    query_idx_end = query_indices[query_idx + 1]
    query_frag = query_frags[query_idx_start:query_idx_end]
    query_int = query_ints[query_idx_start:query_idx_end]

    ax = plt.figure(figsize=(15, 5))

    plt.vlines(query_frag, 0, query_int, "k", label="Query", alpha=0.5)

    plt.vlines(masses, ints, max(query_int)*(1+0.1*ion_type), "k", alpha=0.5, linestyle=':')

    plt.vlines(masses, 0, ints, "r", label="Hits", alpha=0.5)

    for i in range(len(masses)):
        plt.text(masses[i], (1+0.1*ion_type[i])*max(query_int), ion[i], rotation=45)

    figure_title = f"{spectrum['precursor']} - b-hits {spectrum['hits_b']}, y-hits {spectrum['hits_y']}, matched int {spectrum['fragments_matched_int_ratio']*100:.2f} %"

    plt.xlabel("m/z")
    plt.ylabel('Intensity')
    plt.ylim([0, (1+0.2*max(ion_type)+0.1)*max(query_int)])
    plt.legend()
    plt.title(figure_title)
    plt.show()
    
    
for index in range(3):
    precursor = df['precursor'].iloc[index]
    print(f" Plotting PSMS for {precursor}")
    plot_psms(precursor, ms_file)
# Out:
#  Plotting PSMS for GLSATVTGGQK_2
#  Plotting PSMS for FLASVSTVLTSK_2
#  Plotting PSMS for TRFLEGLSEAVTTK_2

# %% [markdown]
# ## MS1 Cluster Annotation
#
# We add additional information from feature finding to the results dataframe, e.g. the intensities of each ms1 peak in the isotope pattern.

# %%
feature_mapping = ms_file.read(dataset_name='feature_cluster_mapping')
display(feature_mapping.head())
feature_table = ms_file.read(dataset_name='feature_table')
feature_table['isotope_mzs'] = feature_mapping.groupby('feature_id')['mz_average'].apply(list)
feature_table['isotope_ints'] = feature_mapping.groupby('feature_id')['int_sum'].apply(list)

df[['isotope_mzs','isotope_ints']] = feature_table.loc[df['feature_idx'].tolist()][['isotope_mzs','isotope_ints']].values

display(df[['sequence','ms1_int_max_apex','isotope_mzs','isotope_ints']])
# Out:
#     delta_m  feature_id    int_area       int_sum  mz_average    rt_max  \
# 0  0.000036           0  27822352.0  1.587311e+06  502.531047  3.944738
# 1  0.000035           0  24784830.0  1.322329e+06  502.865319  4.046092
# 2  0.000049           0  11709788.0  5.794037e+05  503.199507  3.852766
# 3  0.000024           0   7539783.0  4.583391e+05  503.533679  3.880534
# 4  0.000067           0   3973159.0  2.497231e+05  503.867499  3.940195
#
#      rt_min
# 0  3.554484
# 1  3.558843
# 2  3.571734
# 3  3.563944
# 4  3.593494
#           sequence  ms1_int_max_apex  \
# 0      GLSATVTGGQK          628235.0
# 1     FLASVSTVLTSK          599688.0
# 2   TRFLEGLSEAVTTK       260780912.0
# 3    DVFLGMFLYEYAR          457358.0
# 4  DVFLGoxMFLYEYAR          257080.0
#
#                                          isotope_mzs  \
# 0  [509.78076489289543, 510.2829142906923, 510.78...
# 1  [626.8627053714234, 627.3643907872828, 627.866...
# 2  [776.427006529946, 776.9312602110055, 777.4325...
# 3  [812.4018136174758, 812.9034456471884, 813.404...
# 4  [820.3986564843846, 820.9010447067977, 821.402...
#
#                                         isotope_ints
# 0  [15068.544070156297, 8129.717156640652, 1467.3...
# 1  [33384.01514715165, 23971.418937599716, 6687.7...
# 2  [17811.532722010103, 5073580.454575428, 452853...
# 3  [8645.807626287002, 6460.454585379222, 4120.66...
# 4  [3594.325301925297, 3211.583237258589, 1753.01...
