# %% [markdown]
# # Paper Figure 4: ML scoring
#
# Now with arabidopsis FDR estimate.

# %%
import os
from test_files import get_files, prepare_test

files = ['thermo_HeLa.raw', 'human.fasta', 'arabidopsis.fasta']

# %%
tmp_folder = 'F:/projects/alphapept/sandbox/temp'
test_folder = 'fig5'

get_files(tmp_folder, files)
prepare_test(files, tmp_folder, test_folder)
# Out:
# Creating dir F:/projects/alphapept/sandbox/temp\fig5.

# %% [markdown]
# ## Search raw file

# %%
import alphapept.settings
import alphapept.paths
import alphapept.interface

test_folder = os.path.join(tmp_folder, test_folder)

file_name = os.path.join(test_folder, files[0])
settings = alphapept.settings.load_settings(alphapept.paths.DEFAULT_SETTINGS_PATH)
settings['experiment']['file_paths'] = [file_name]
settings['experiment']['fasta_paths'] = [os.path.join(test_folder, _) for _ in ['human.fasta', 'arabidopsis.fasta']]
settings_ = alphapept.interface.run_complete_workflow(settings)
base, ext = os.path.splitext(file_name)
# Out:
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\cupy\_environment.py:213: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(
# 2022-12-01 16:30:06> Logging to C:\Users\admin\alphapept\logs\log_20221201163006.txt.
# 2022-12-01 16:30:06> Code location f:\projects\alphapept\alphapept
# 2022-12-01 16:30:06> Python location C:\Users\admin\.conda\envs\alphapept-gpu\python.exe
# 2022-12-01 16:30:06> Platform information:
# 2022-12-01 16:30:06> system     - Windows
# 2022-12-01 16:30:06> release    - 10
# 2022-12-01 16:30:06> version    - 10.0.19044
# 2022-12-01 16:30:06> machine    - AMD64
# 2022-12-01 16:30:06> processor  - Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# 2022-12-01 16:30:06> cpu count  - 24
# 2022-12-01 16:30:06> ram memory - 109.3/127.7 Gb (available/total)
# 2022-12-01 16:30:06> processor  - Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# 2022-12-01 16:30:06> Python information:
# 2022-12-01 16:30:06> SQLAlchemy                    - 1.4.44
# 2022-12-01 16:30:06> alphapept                     - 0.4.9
# 2022-12-01 16:30:06> biopython                     - 1.80
# 2022-12-01 16:30:06> bumpversion                   -
# 2022-12-01 16:30:06> bumpversion>                  -
# 2022-12-01 16:30:06> click                         - 8.1.3
# 2022-12-01 16:30:06> click>                        -
# 2022-12-01 16:30:06> fastcore                      - 1.5.26
# 2022-12-01 16:30:06> h5py                          - 3.7.0
# 2022-12-01 16:30:06> jupyter                       - 1.0.0
# 2022-12-01 16:30:06> jupyter>                      -
# 2022-12-01 16:30:06> jupyter_contrib_nbextensions  -
# 2022-12-01 16:30:06> jupyter_contrib_nbextensions> -
# 2022-12-01 16:30:06> matplotlib                    - 3.6.2
# 2022-12-01 16:30:06> nbdev                         -
# 2022-12-01 16:30:06> nbdev>                        -
# 2022-12-01 16:30:06> networkx                      - 2.8.8
# 2022-12-01 16:30:06> numba                         - 0.56.3
# 2022-12-01 16:30:06> numpy                         - 1.21.5
# 2022-12-01 16:30:06> pandas                        - 1.5.1
# 2022-12-01 16:30:06> plotly_express                -
# 2022-12-01 16:30:06> psutil                        - 5.9.0
# 2022-12-01 16:30:06> pyinstaller                   -
# 2022-12-01 16:30:06> pyteomics                     - 4.5.6
# 2022-12-01 16:30:06> python                        - 3.8.15
# 2022-12-01 16:30:06> pythonnet                     - 2.5.2
# 2022-12-01 16:30:06> pywin32                       - 225
# 2022-12-01 16:30:06> pyyaml                        - 6.0
# 2022-12-01 16:30:06> scikit-learn                  - 1.1.3
# 2022-12-01 16:30:06> scipy                         - 1.9.3
# 2022-12-01 16:30:06> streamlit                     -
# 2022-12-01 16:30:06> streamlit-aggrid              -
# 2022-12-01 16:30:06> streamlit>                    -
# 2022-12-01 16:30:06> tables                        - 3.6.1
# 2022-12-01 16:30:06> tqdm                          - 4.64.1
# 2022-12-01 16:30:06> twine                         -
# 2022-12-01 16:30:06> twine>                        -
# 2022-12-01 16:30:06> watchdog                      -
# 2022-12-01 16:30:06> wget                          - 3.2
# 2022-12-01 16:30:06>
# 2022-12-01 16:30:06> Check for settings not completely implemented yet.
# 2022-12-01 16:30:06> Size check:
# 2022-12-01 16:30:06> Size of job (raw files) 3.05 Gb
# 2022-12-01 16:30:06> Required disk space for F: - 3.05 Gb, Available 454.93 Gb OK.
# 2022-12-01 16:30:06>
# 2022-12-01 16:30:06> Workflow Settings:
# 2022-12-01 16:30:06> align              - False
# 2022-12-01 16:30:06> continue_runs      - False
# 2022-12-01 16:30:06> create_database    - True
# 2022-12-01 16:30:06> find_features      - True
# 2022-12-01 16:30:06> import_raw_data    - True
# 2022-12-01 16:30:06> lfq_quantification - True
# 2022-12-01 16:30:06> match              - False
# 2022-12-01 16:30:06> recalibrate_data   - True
# 2022-12-01 16:30:06> search_data        - True
# 2022-12-01 16:30:06>
# 2022-12-01 16:30:06> Checking if files exist.
# 2022-12-01 16:30:06> FASTA Files have a total size of 21.807 Mb
# 2022-12-01 16:30:06> Results path was not set. Setting to F:\projects\alphapept\sandbox\temp\fig5\results.hdf
# 2022-12-01 16:30:06> Shortnames not set. Setting to filename.
# 2022-12-01 16:30:06> Sample group not set. Setting to shortname.
# 2022-12-01 16:30:06> Fraction not set. Setting to 1.
# 2022-12-01 16:30:06> No database path set and save_db option checked. Using default path F:\projects\alphapept\sandbox\temp\fig5\database.hdf
# 2022-12-01 16:30:06> Workflow has 11 steps
# 2022-12-01 16:30:06> ==== create_database ====
# 2022-12-01 16:30:06> Database path F:\projects\alphapept\sandbox\temp\fig5\database.hdf is not a file.
# 2022-12-01 16:30:06> Found FASTA file F:/projects/alphapept/sandbox/temp\fig5\human.fasta with size 12.97 Mb.
# 2022-12-01 16:30:06> Found FASTA file F:/projects/alphapept/sandbox/temp\fig5\arabidopsis.fasta with size 8.84 Mb.
# 2022-12-01 16:30:06> Creating a new database from FASTA.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:30:07> FASTA contains 36,543 entries.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1.0/1 [02:21<00:00, 38.96s/it]
# 2022-12-01 16:32:46> Digested 36,543 proteins and generated 8,593,674 spectra
# 2022-12-01 16:34:06> Database saved to F:\projects\alphapept\sandbox\temp\fig5\database.hdf. Filesize of database is 3.31 GB
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1.0/1 [04:00<00:00, 240.08s/it]
# 2022-12-01 16:34:19> ==== import_raw_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:34:19> Processing 1 files for step raw_conversion
# 2022-12-01 16:34:19> File F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa has extension .raw - converting from Thermo.
# 2022-12-01 16:36:19> File conversion complete. Extracted 120,226 precursors.
# 2022-12-01 16:36:20> File conversion of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw complete.
#   0%|                                                                                            | 0/1 [02:01<?, ?it/s]
# 2022-12-01 16:36:21> ==== feature_finding ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:36:22> Processing 1 files for step find_features
# 2022-12-01 16:36:22> No *.hdf file with features found for F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf. Adding to feature finding list.
# 2022-12-01 16:36:23> Feature finding on F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw
# 2022-12-01 16:36:23> Hill extraction with centroid_tol 8 and max_gap 2
# 2022-12-01 16:36:25> Number of hills 1,105,353, len = 17.35
# 2022-12-01 16:36:25> Repeating hill extraction with centroid_tol 5.87
# 2022-12-01 16:36:27> Number of hills 1,227,331, len = 19.44
# 2022-12-01 16:36:30> After duplicate removal of hills 1,025,845
# 2022-12-01 16:36:47> After split hill_ptrs 1,207,373
# 2022-12-01 16:36:49> After filter hill_ptrs 1,188,406
# 2022-12-01 16:38:58> Extracting hill stats complete
# 2022-12-01 16:39:12> Found 184,383 pre isotope patterns.
# 2022-12-01 16:40:13> Extracted 198,500 isotope patterns.
# 2022-12-01 16:40:26> Report complete.
# 2022-12-01 16:40:26> Matching features to query data.
# 2022-12-01 16:40:27> Saving feature table.
# 2022-12-01 16:40:28> Feature table saved to F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf
# 2022-12-01 16:40:28> Saving features.
# 2022-12-01 16:40:28> Feature finding of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw complete.
#   0%|                                                                                            | 0/1 [04:05<?, ?it/s]
# 2022-12-01 16:40:28> ==== search_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:40:28> Starting first search.
# 2022-12-01 16:40:28> Processing 1 files for step search_db
# 2022-12-01 16:40:28> Calibrating fragments
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 2022-12-01 16:40:43> Performing search on 246,847 query and 8,593,674 db entries with frag_tol = 50.00 and prec_tol = 20.00.
# 2022-12-01 16:42:43> Found 774,993 psms.
# 2022-12-01 16:42:43> Extracting columns for scoring.
# 2022-12-01 16:44:43> Extracted columns from 774,993 spectra.
# 2022-12-01 16:44:43> Saving first_search results to F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf
# 2022-12-01 16:44:47> Search of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw complete.
# 2022-12-01 16:45:14> First search complete.
#   0%|                                                                                            | 0/1 [04:45<?, ?it/s]
# 2022-12-01 16:45:14> ==== recalibrate_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:45:14> Processing 1 files for step calibrate_hdf
# 2022-12-01 16:45:14> Recalibrating file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw.
# 2022-12-01 16:45:15> Scoring using generic score
# 2022-12-01 16:45:16> 41,360 target (413 decoy) of 137,593 PSMs. FDR 0.009985 for a cutoff of 12.34 (set FDR was 0.01).
# 2022-12-01 16:45:16> Precursor mass calibration for file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw.
# 2022-12-01 16:45:20> Precursor calibration std 0.24, 0.00
# 2022-12-01 16:45:20> Saving precursor calibration
# 2022-12-01 16:45:25> Precursor calibration of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf complete.
# 2022-12-01 16:45:25> Starting fragment calibration.
# 2022-12-01 16:45:25> Calibrating fragments with neighbors
# 2022-12-01 16:45:27> Scoring using generic score
# 2022-12-01 16:45:28> 41,360 target (413 decoy) of 137,593 PSMs. FDR 0.009985 for a cutoff of 12.34 (set FDR was 0.01).
# 2022-12-01 16:45:30> Minimum hits for fragments before score 7.00.
# 2022-12-01 16:45:30> Minimum hits for fragments after score 7.42.
# 2022-12-01 16:45:58> Median offset (std) 11.41 (7.95) - after calibration 0.00 (6.46) Mad offset 2.00
# 2022-12-01 16:45:58> Saving calibration
# 2022-12-01 16:47:08> Fragment calibration of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf complete.
#   0%|                                                                                            | 0/1 [01:54<?, ?it/s]
# 2022-12-01 16:47:08> ==== search_data ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:47:08> Starting second search with DB.
# 2022-12-01 16:47:08> Processing 1 files for step search_db
# 2022-12-01 16:47:08> Found calibrated prec_tol with value 1.19
# 2022-12-01 16:47:08> Found calibrated frag_tol with value 32.28
# 2022-12-01 16:47:11> Performing search on 246,847 query and 8,593,674 db entries with frag_tol = 32.28 and prec_tol = 1.19.
# 2022-12-01 16:47:20> Found 266,845 psms.
# 2022-12-01 16:47:20> Extracting columns for scoring.
# 2022-12-01 16:48:01> Extracted columns from 266,845 spectra.
# 2022-12-01 16:48:01> Saving second_search results to F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.ms_data.hdf
# 2022-12-01 16:48:03> Search of file F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw complete.
# 2022-12-01 16:48:28> Second search complete.
#   0%|                                                                                            | 0/1 [01:19<?, ?it/s]
# 2022-12-01 16:48:29> ==== score ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:48:29> Processing 1 files for step score_hdf
# 2022-12-01 16:48:29> Calling score_hdf
# 2022-12-01 16:48:29> Found second search psms for scoring.
# 2022-12-01 16:48:34> 57,655 target (5,765 decoy) of 81,477 PSMs. FDR 0.099991 for a cutoff of 20.62 (set FDR was 0.1).
# 2022-12-01 16:48:35> Training & cross-validation on 12,192 targets and 12,192 decoys
# 2022-12-01 16:48:56> The best parameters selected by 5-fold cross-validation were {'clf__max_depth': 50, 'clf__max_leaf_nodes': 250}
# 2022-12-01 16:48:56> The train accuracy was 0.947
# 2022-12-01 16:48:56> Testing on 48,769 targets and 48,769 decoys
# 2022-12-01 16:48:57> The test accuracy was 0.918
# 2022-12-01 16:48:57> ML Top features
# 2022-12-01 16:48:57> 1	generic_score                  0.2013
# 2022-12-01 16:48:57> 2	hits_y                         0.1837
# 2022-12-01 16:48:57> 3	x_tandem                       0.1340
# 2022-12-01 16:48:57> 4	hits                           0.0975
# 2022-12-01 16:48:57> 5	n_fragments_matched            0.0626
# 2022-12-01 16:48:57> 6	fragments_matched_n_ratio      0.0506
# 2022-12-01 16:48:57> 7	fragments_matched_int_ratio    0.0425
# 2022-12-01 16:48:57> 8	fragments_matched_int_sum      0.0282
# 2022-12-01 16:48:57> 9	delta_m_ppm_abs                0.0181
# 2022-12-01 16:48:57> 10	n_missed                       0.0176
# 2022-12-01 16:48:57> 11	prec_offset                    0.0162
# 2022-12-01 16:48:57> 12	prec_offset_ppm                0.0162
# 2022-12-01 16:48:57> 13	hits_y-NH3                     0.0115
# 2022-12-01 16:48:57> 14	hits_b                         0.0115
# 2022-12-01 16:48:57> 15	mz                             0.0088
# 2022-12-01 16:48:57> 16	delta_m_ppm                    0.0074
# 2022-12-01 16:48:57> 17	hits_y-H2O                     0.0071
# 2022-12-01 16:48:57> 18	charge                         0.0060
# 2022-12-01 16:48:57> 19	fragments_int_ratio            0.0060
# 2022-12-01 16:48:57> 20	ms1_int_max_apex               0.0053
# 2022-12-01 16:48:57> 21	mass                           0.0051
# 2022-12-01 16:48:57> 22	ms1_int_sum_apex               0.0050
# 2022-12-01 16:48:57> 23	ms1_int_max_area               0.0050
# 2022-12-01 16:48:57> 24	fragments_int_sum              0.0047
# 2022-12-01 16:48:57> 25	delta_m                        0.0046
# 2022-12-01 16:48:57> 26	ms1_int_sum_area               0.0046
# 2022-12-01 16:48:57> 27	mass_db                        0.0046
# 2022-12-01 16:48:57> 28	prec_offset_raw_ppm            0.0041
# 2022-12-01 16:48:57> 29	fwhm                           0.0035
# 2022-12-01 16:48:57> 30	prec_offset_raw                0.0035
# 2022-12-01 16:48:57> 31	rt_start                       0.0032
# 2022-12-01 16:48:57> 32	scan_no                        0.0030
# 2022-12-01 16:48:57> 33	rt_end                         0.0027
# 2022-12-01 16:48:57> 34	hits_b-H2O                     0.0026
# 2022-12-01 16:48:57> 35	n_frags_db                     0.0026
# 2022-12-01 16:48:57> 36	rt                             0.0025
# 2022-12-01 16:48:57> 37	rt_apex                        0.0024
# 2022-12-01 16:48:57> 38	hits_b-NH3                     0.0022
# 2022-12-01 16:48:57> 39	n_AA                           0.0018
# 2022-12-01 16:48:57> 40	n_internal                     0.0002
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 2022-12-01 16:49:00> 83,315 target (833 decoy) of 122,037 PSMs. FDR 0.009998 for a cutoff of 0.62 (set FDR was 0.01).
# 2022-12-01 16:49:00> Saving identifications to ms_data file.
# 2022-12-01 16:49:01> Saving identifications to ms_data file complete.
# 2022-12-01 16:49:06> Saving identifications to csv file complete.
# 2022-12-01 16:49:06> Filter df with custom score
# 2022-12-01 16:49:06> Global FDR on precursor
# 2022-12-01 16:49:06> 51,038 target (510 decoy) of 81,205 PSMs. FDR 0.009993 for a cutoff of 0.71 (set FDR was 0.01).
# 2022-12-01 16:49:06> Global FDR cutoff at 0.707.
# 2022-12-01 16:49:07> FDR on peptides complete. For 0.01 FDR found 51,744 targets and 510 decoys.
# 2022-12-01 16:49:07> Extracting fragment_ions
# 2022-12-01 16:49:20> Extracting fragment_ions complete.
# 2022-12-01 16:49:20> Exporting peptide_fdr on F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw.
# 2022-12-01 16:49:21> Scoring of files F:/projects/alphapept/sandbox/temp\fig5\thermo_HeLa.raw complete.
#   0%|                                                                                            | 0/1 [00:52<?, ?it/s]
# 2022-12-01 16:49:21> ==== isobaric_labeling ====
# 2022-12-01 16:49:21> ==== protein_grouping ====
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:49:21> Fasta dict with length 36,543, Pept dict with length 8,593,678
# 2022-12-01 16:49:21> Extracting protein groups.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:49:22> A total of 41,805 unique and 2,663 shared peptides.
# 2022-12-01 16:49:23> A total of 849 ambigious proteins
# 2022-12-01 16:49:23> A total of 481 unique and 28 shared peptides.
# 2022-12-01 16:49:23> A total of 28 ambigious proteins
# 2022-12-01 16:49:23> Global FDR on protein_group
# 2022-12-01 16:49:23> 5,869 target (58 decoy) of 7,027 PSMs. FDR 0.009882 for a cutoff of 0.94 (set FDR was 0.01).
# 2022-12-01 16:49:23> Global FDR cutoff at 0.945.
# 2022-12-01 16:49:23> FDR on proteins complete. For 0.01 FDR found 51,022 targets and 59 decoys. A total of 5,927 proteins found.
# 2022-12-01 16:49:24> Saving complete.
# 2022-12-01 16:49:24> Protein groups complete.
#   0%|                                                                                            | 0/1 [00:02<?, ?it/s]
# 2022-12-01 16:49:24> ==== quantification ====
# 2022-12-01 16:49:24> Reading protein_fdr for quantification.
# 2022-12-01 16:49:24> Saving protein_groups after delayed normalization to combined_protein_fdr_dn
# 2022-12-01 16:49:24> Complete.
# 2022-12-01 16:49:24> Starting profile extraction.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2022-12-01 16:49:24> LFQ complete.
# 2022-12-01 16:49:24> Extracting protein_summary
# 2022-12-01 16:49:24> Saved protein_summary of length 5,927 saved to F:\projects\alphapept\sandbox\temp\fig5\results_protein_summary.csv
# 2022-12-01 16:49:24> Updating protein_fdr.
# 2022-12-01 16:49:25> Exporting as csv.
# 2022-12-01 16:49:27> Saved df of length 51,081 saved to F:\projects\alphapept\sandbox\temp\fig5\results
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.90s/it]
# 2022-12-01 16:49:27> ==== export ====
# 2022-12-01 16:49:30> Settings saved to F:\projects\alphapept\sandbox\temp\fig5\results.yaml
# 2022-12-01 16:49:30> Analysis complete.

# %%
import alphapept.io
from alphapept.score import get_ML_features, filter_with_ML, filter_with_x_tandem, cut_global_fdr, train_RF, filter_score, filter_precursor, cut_fdr

ms_file = alphapept.io.MS_Data_File(os.path.join(test_folder,'thermo_HeLa.ms_data.hdf'))

df = ms_file.read(dataset_name='second_search')
df_ = get_ML_features(df)

df = df_.copy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

import logging
import numpy as np

import matplotlib.pyplot as plt

exclude_features = ['precursor_idx', 'fragment_ion_idx', 'fasta_index', 'feature_rank', 'raw_rank',
                                       'score_rank', 'db_idx', 'feature_idx', 'precursor', 'query_idx', 'raw_idx',
                                       'sequence', 'decoy', 'sequence_naked', 'target']
train_fdr_level = 0.1
ini_score = 'x_tandem'
min_train = 1000
test_size = 0.8
max_depth = [5,25,50]
max_leaf_nodes = [150,200,250]
n_jobs=-1
scoring='accuracy'
plot = True
random_state = 42

features = [_ for _ in df.columns if _ not in exclude_features]

# Setup ML pipeline
scaler = StandardScaler()
rfc = RandomForestClassifier(random_state=random_state) # class_weight={False:1,True:5},
## Initiate scaling + classification pipeline
pipeline = Pipeline([('scaler', scaler), ('clf', rfc)])
parameters = {'clf__max_depth':(max_depth), 'clf__max_leaf_nodes': (max_leaf_nodes)}
## Setup grid search framework for parameter selection and internal cross validation
cv = GridSearchCV(pipeline, param_grid=parameters, cv=5, scoring=scoring,
                 verbose=0,return_train_score=True,n_jobs=n_jobs)

# Prepare target and decoy df
df['decoy'] = df['sequence'].str[-1].str.islower()
df['target'] = ~df['decoy']
df['score'] = df[ini_score]
dfT = df[~df.decoy]
dfD = df[df.decoy]

# Select high scoring targets (<= train_fdr_level)
df_prescore = filter_score(df)
df_prescore = filter_precursor(df_prescore)
scored = cut_fdr(df_prescore, fdr_level = train_fdr_level, plot=False)[1]
highT = scored[scored.decoy==False]
dfT_high = dfT[dfT['query_idx'].isin(highT.query_idx)]
dfT_high = dfT_high[dfT_high['db_idx'].isin(highT.db_idx)]

# Determine the number of psms for semi-supervised learning
n_train = int(dfT_high.shape[0])
if dfD.shape[0] < n_train:
    n_train = int(dfD.shape[0])
    logging.info("The total number of available decoys is lower than the initial set of high scoring targets.")
if n_train < min_train:
    raise ValueError("There are fewer high scoring targets or decoys than required by 'min_train'.")

# Subset the targets and decoys datasets to result in a balanced dataset
df_training = dfT_high.sample(n=n_train, random_state=random_state).append(dfD.sample(n=n_train, random_state=random_state))

# Select training and test sets
X = df_training[features]
y = df_training['target'].astype(int)
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, test_size=test_size, random_state=random_state, stratify=y.values)

# Train the classifier on the training set via 5-fold cross-validation and subsequently test on the test set
logging.info('Training & cross-validation on {} targets and {} decoys'.format(np.sum(y_train),X_train.shape[0]-np.sum(y_train)))
cv.fit(X_train,y_train)

logging.info('The best parameters selected by 5-fold cross-validation were {}'.format(cv.best_params_))
logging.info('The train {} was {}'.format(scoring, cv.score(X_train, y_train)))
logging.info('Testing on {} targets and {} decoys'.format(np.sum(y_test),X_test.shape[0]-np.sum(y_test)))
logging.info('The test {} was {}'.format(scoring, cv.score(X_test, y_test)))

feature_importances=cv.best_estimator_.named_steps['clf'].feature_importances_
indices = np.argsort(feature_importances)[::-1][:40]

top_features = X.columns[indices][:40]
top_score = feature_importances[indices][:40]

feature_dict = dict(zip(top_features, top_score))
logging.info(f"Top features {feature_dict}")

# Inspect feature importances
if plot:
    import seaborn as sns
    g = sns.barplot(y=X.columns[indices][:40],
                    x = feature_importances[indices][:40],
                    orient='h', palette='RdBu')
    g.set_xlabel("Relative importance",fontsize=12)
    g.set_ylabel("Features",fontsize=12)
    g.tick_params(labelsize=9)
    g.set_title("Feature importance")
    plt.show()
# Out:
# 2022-12-01 16:55:50> 57,655 target (5,765 decoy) of 81,477 PSMs. FDR 0.099991 for a cutoff of 20.62 (set FDR was 0.1).
# C:\Users\admin\AppData\Local\Temp\ipykernel_7372\2005729528.py:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_training = dfT_high.sample(n=n_train, random_state=random_state).append(dfD.sample(n=n_train, random_state=random_state))
# 2022-12-01 16:55:50> Training & cross-validation on 12192 targets and 12192 decoys
# 2022-12-01 16:56:07> The best parameters selected by 5-fold cross-validation were {'clf__max_depth': 25, 'clf__max_leaf_nodes': 250}
# 2022-12-01 16:56:07> The train accuracy was 0.9495160761154856
# 2022-12-01 16:56:07> Testing on 48769 targets and 48769 decoys
# 2022-12-01 16:56:08> The test accuracy was 0.9173245299267978
# 2022-12-01 16:56:08> Top features {'hits_y': 0.19608149607424596, 'generic_score': 0.19111315217456626, 'score': 0.10794365709286816, 'x_tandem': 0.10672544628563696, 'hits': 0.09466978507344184, 'n_fragments_matched': 0.037482134932436545, 'fragments_matched_n_ratio': 0.02938840398133283, 'fragments_matched_int_ratio': 0.026099996533406455, 'delta_m_ppm_abs': 0.01923800910788698, 'fragments_matched_int_sum': 0.0184098568145339, 'prec_offset': 0.016075918464176022, 'prec_offset_ppm': 0.01543369140017334, 'n_missed': 0.015227494101653362, 'hits_y-NH3': 0.011336567343838038, 'mz': 0.00926766657013929, 'hits_b': 0.009176779902510555, 'hits_y-H2O': 0.00704143378495253, 'delta_m_ppm': 0.006524453676467959, 'mass': 0.005626642414808623, 'ms1_int_max_apex': 0.00536686503307084, 'mass_db': 0.004912492644944812, 'ms1_int_sum_apex': 0.004877593439415564, 'charge': 0.004854605734783788, 'ms1_int_max_area': 0.004734536791459766, 'delta_m': 0.004715427170127008, 'hits_b-H2O': 0.004670887729617178, 'ms1_int_sum_area': 0.0046605915807454434, 'prec_offset_raw_ppm': 0.00417192269876457, 'fragments_int_ratio': 0.0039692579417834745, 'prec_offset_raw': 0.003648259917933054, 'fragments_int_sum': 0.0035762880804079454, 'fwhm': 0.0032608380637013114, 'rt': 0.0029831158863043265, 'rt_start': 0.0028474246985384466, 'rt_apex': 0.002741434645194389, 'rt_end': 0.0026545153679677106, 'scan_no': 0.002603444611946754, 'n_AA': 0.002220213120530932, 'n_frags_db': 0.001940565959018228, 'hits_b-NH3': 0.0015089204606886025}

# %%
dark_blue = '#17212b'
light_blue = '#3dc5ef'
teal= '#42dee1'
green = '#6eecb9'
yellow = '#eef5b3'
hfont = {'fontname':'Arial', 'size':10}

colors = [dark_blue, light_blue, teal, green, yellow]

plt.figure(figsize=(2.363*1.5,2.363)) #60x60

height=0.5
top_n = 10
color_index = 3

y = list(X.columns[indices][:top_n][::-1])
x = feature_importances[indices][:top_n][::-1]

remainder = feature_importances[indices][top_n:].sum()

x = np.append(remainder, x)
y = ['Remainder'] + y

plt.barh(y, x, height, color = colors[color_index], linewidth=1, edgecolor='black')

plt.xticks(**hfont)
plt.yticks(**hfont)
plt.xlabel('Relative importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('figures/04_feature_importance.pdf')  
plt.show()

# %%
df = filter_with_x_tandem(df_)

decoy_ = df[df["decoy"]]['score']
target_ = df[~df["decoy"]]['score']

plt.figure(figsize=(2.363, 2.363)) #60x60

bins = np.linspace(df['score'].min(), 75, 60)
histogram, bins = np.histogram(decoy_, bins=bins, density=True)
histogram_, bins = np.histogram(target_, bins=bins, density=True)

bin_centers = 0.5*(bins[1:] + bins[:-1])

plt.plot(bin_centers, histogram_, color=colors[1], label='Target')
plt.fill_between(bin_centers, histogram_, alpha=0.7, color=colors[1])

plt.plot(bin_centers, histogram, color=colors[0], label='Decoy')
plt.fill_between(bin_centers, histogram, alpha=0.7, color=colors[0])

plt.xticks(**hfont)
plt.yticks(**hfont)
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.title('X!')
plt.tight_layout()
plt.savefig('figures/04_x_score.pdf')
plt.show()
# Out:
# 2022-12-01 16:59:04> Filter df with x_tandem score

# %%
df = filter_with_ML(df_, cv, features = features)

decoy_ = df[df["decoy"]]['score']
target_ = df[~df["decoy"]]['score']

plt.figure(figsize=(2.363, 2.363)) #60x60

bins = np.linspace(0, 1, 60)
histogram, bins = np.histogram(decoy_, bins=bins, density=True)
histogram_, bins = np.histogram(target_, bins=bins, density=True)

bin_centers = 0.5*(bins[1:] + bins[:-1])

plt.plot(bin_centers, histogram_, color=colors[1], label='Target')
plt.fill_between(bin_centers, histogram_, alpha=0.7, color=colors[1])

plt.plot(bin_centers, histogram, color=colors[0], label='Decoy')
plt.fill_between(bin_centers, histogram, alpha=0.7, color=colors[0])

plt.xticks(**hfont)
plt.yticks(**hfont)
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend(loc='upper left')
plt.title('ML')
plt.tight_layout()
plt.savefig('figures/04_ml_score.pdf')
plt.show()
# Out:
# 2022-12-01 16:59:04> Filter df with x_tandem score
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
df_ml = filter_with_ML(df_, cv, features = features)
df_x = filter_with_x_tandem(df_)
# Out:
# 2022-12-01 16:59:08> Filter df with x_tandem score
# C:\Users\admin\.conda\envs\alphapept-gpu\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 2022-12-01 16:59:11> Filter df with x_tandem score

# %%
df_ml_fdr = cut_global_fdr(df_ml, analyte_level='precursor')
df_x_fdr = cut_global_fdr(df_x, analyte_level='precursor')
# Out:
# 2022-12-01 16:59:11> Global FDR on precursor
# 2022-12-01 16:59:11> 51,084 target (510 decoy) of 81,180 PSMs. FDR 0.009984 for a cutoff of 0.71 (set FDR was 0.01).
# 2022-12-01 16:59:12> Global FDR cutoff at 0.707.
# 2022-12-01 16:59:12> Global FDR on precursor
# 2022-12-01 16:59:12> 44,404 target (444 decoy) of 81,442 PSMs. FDR 0.009999 for a cutoff of 24.67 (set FDR was 0.01).
# 2022-12-01 16:59:13> Global FDR cutoff at 24.672.

# %%
df_ml_fdr = df_ml_fdr.sort_values(by='q_value')
df_ml_fdr = df_ml_fdr.reset_index(drop=True)

df_x_fdr = df_x_fdr.sort_values(by='q_value')
df_x_fdr = df_x_fdr.reset_index(drop=True)

# %%
plt.figure(figsize=(2.363, 2.363)) #60x60
plt.plot(df_ml_fdr['q_value'], df_ml_fdr.index, label='ML', color = colors[3])
plt.plot(df_x_fdr['q_value'], df_x_fdr.index, label ='X!', color = colors[0])
plt.xlabel('q-value')
plt.ylabel('Identified PSMs')

plt.yticks([0, 1e4, 2e4, 3e4, 4e4, 5e4, 6e4])
plt.xticks([0.00, 0.005, 0.01])
plt.tight_layout()
plt.legend(loc='lower right')
plt.xticks(**hfont)
plt.yticks(**hfont)
plt.savefig('figures/04_psms.pdf')  
plt.show()

# %%
import alphapept.fasta

# %%
db = alphapept.fasta.read_database(os.path.join(test_folder,'database.hdf'))

# %%
pept_dict = db['pept_dict'].item()
fasta_dict = db['fasta_dict'].item()

# %%
df_ml_cp = df_ml.copy()

proteins = df_ml['sequence'].apply(lambda x: [fasta_dict[y]['name'] for y in pept_dict[x]])

list_ = []


for _ in proteins:
    hum = 0
    ara = 0
    for k in _:
        if 'HUM' in k:
            hum +=1
        if 'ARA' in k:
            ara +=1

    if (ara == 0) and (hum > 0):
        list_.append('HUM')
    elif (hum == 0) and (ara > 0):
        list_.append('ARA')
    else:

        list_.append('X')

# %%
df_ml_cp['species'] = list_

# %%
sorted_ = df_ml_cp[['species','score','decoy']].sort_values('score')[::-1]

# %%
sorted_['HUM_cum'] = np.cumsum(sorted_['species'] == 'HUM')
sorted_['ARA_cum'] = np.cumsum(sorted_['species'] == 'ARA')
sorted_['X_cum'] = np.cumsum(sorted_['species'] == 'X')
sorted_['decoy_cum'] = np.cumsum(sorted_['decoy'])

# %%
sorted_['species'].value_counts()
# Out:
# HUM    70036
# ARA    11520
# X        569
# Name: species, dtype: int64

# %%
from alphapept.score import get_q_values

# %%
df_ml_fdr_ = df_ml_fdr.copy()

proteins = df_ml_fdr_['sequence'].apply(lambda x: [fasta_dict[y]['name'] for y in pept_dict[x]])

list_ = []

for _ in proteins:
    hum = 0
    ara = 0
    for k in _:
        if 'HUM' in k:
            hum +=1
        if 'ARA' in k:
            ara +=1

    if (ara == 0) and (hum > 0):
        list_.append('HUM')
    elif (hum == 0) and (ara > 0):
        list_.append('ARA')
    else:
        list_.append('X')
        
df_ml_fdr_['species'] = list_ 


df_ml_fdr_['ARA_cum'] = np.cumsum(df_ml_fdr_['species'] == 'ARA')
df_ml_fdr_['ARA_cum_q'] = get_q_values(df_ml_fdr_['ARA_cum'].values/ np.arange(1, len(df_ml_fdr_)+1))

df_x_fdr_ = df_x_fdr.copy()

proteins = df_x_fdr_['sequence'].apply(lambda x: [fasta_dict[y]['name'] for y in pept_dict[x]])

list_ = []

for _ in proteins:
    hum = 0
    ara = 0
    for k in _:
        if 'HUM' in k:
            hum +=1
        if 'ARA' in k:
            ara +=1

    if (ara == 0) and (hum > 0):
        list_.append('HUM')
    elif (hum == 0) and (ara > 0):
        list_.append('ARA')
    else:
        list_.append('X')
        
df_x_fdr_['species'] = list_ 


df_x_fdr_['ARA_cum'] = np.cumsum(df_x_fdr_['species'] == 'ARA')
df_x_fdr_['ARA_cum_q'] = get_q_values(df_x_fdr_['ARA_cum'].values/ np.arange(1, len(df_x_fdr_)+1))

# %%
plt.figure(figsize=(2.363, 2.363)) #60x60

plt.plot(df_ml_fdr_['ARA_cum_q'], df_ml_fdr_.index, label='ML', color = colors[3])
plt.plot(df_x_fdr_['ARA_cum_q'], df_x_fdr_.index, label='X!', color = colors[0])
#plt.plot(df_x_fdr['q_value'], df_x_fdr.index, label ='X!', color = colors[0])
plt.xlabel('q-value')
plt.ylabel('Identified PSMs')

plt.yticks([0, 1e4, 2e4, 3e4, 4e4, 5e4, 6e4])
plt.xticks([0.00, 0.005, 0.01])
plt.tight_layout()
plt.legend(loc='lower right')
plt.xticks(**hfont)
plt.yticks(**hfont)
plt.savefig('figures/04_q.pdf')  
plt.show()
