# %% [markdown]
# # AlphaPept Test Runs and Visualization Examples
#
# This notebooks is intended to show how a HeLa File can be processed.

# %% [markdown]
# ## Download Test Data

# %%
import os
try:
    import wget
except ModuleNotFoundError:
    # !pip install wget
    
FILE_DICT = {}
FILE_DICT['thermo_IRT.raw'] = 'https://datashare.biochem.mpg.de/s/GpXsATZtMwgQoQt/download'
FILE_DICT['IRT_fasta.fasta'] = 'https://datashare.biochem.mpg.de/s/p8Qu3KolzbSiCHH/download'

tmp_folder = os.path.join(os.getcwd(),'/temp')

if not os.path.isdir(tmp_folder):
    os.mkdir(tmp_folder)
    
for file in FILE_DICT:
    target = os.path.join(tmp_folder, file)
    if not os.path.isfile(target):
        wget.download(FILE_DICT[file], target)

# %% [markdown]
# ## Test Run

# %%
from alphapept.settings import load_settings
settings = load_settings('default_settings.yaml')

settings['experiment']['file_paths'] =  [os.path.join(tmp_folder, 'thermo_IRT.raw')]
settings['fasta']['fasta_paths'] = [os.path.join(tmp_folder, 'IRT_fasta.fasta')]
    
import alphapept.interface

settings_ = alphapept.interface.run_complete_workflow(settings)
# Out:
# 2021-01-09 23:32:40 INFO - Currently 122.26 GB of memory available.
# 2021-01-09 23:32:40 INFO - System information: uname_result(system='Windows', node='PCMANN338', release='10', version='10.0.18362', machine='AMD64', processor='Intel64 Family 6 Model 85 Stepping 4, GenuineIntel')
# 2021-01-09 23:32:40 INFO - AlphaPept version 0.3.9-dev0
# 2021-01-09 23:32:40 INFO - Python version 3.8.6 | packaged by conda-forge | (default, Nov 27 2020, 18:58:29) [MSC v.1916 64 bit (AMD64)]
# 2021-01-09 23:32:40 INFO - Numba version 0.51.2
# 2021-01-09 23:32:40 INFO - Check for settings not completely implemented yet.
# 2021-01-09 23:32:40 INFO - Checking CPU settings.
# 2021-01-09 23:32:40 INFO - Setting number of processes to 24.
# 2021-01-09 23:32:40 INFO - Checking if files exist.
# 2021-01-09 23:32:40 INFO - Results path was not set. Setting to F:\temp\results.hdf
# 2021-01-09 23:32:40 INFO - Shortnames not set. Setting to filename.
# 2021-01-09 23:32:40 INFO - No database path set and save_db option checked. Using default path F:\temp\database.hdf
# 2021-01-09 23:32:40 INFO - Workflow has 10 steps
# 2021-01-09 23:32:40 INFO - Database path set and exists. Using F:\temp\database.hdf as database.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:40 INFO - Processing 1 files for step raw_conversion
# 2021-01-09 23:32:40 INFO - File conversion of file F:/temp\thermo_IRT.raw complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:42 INFO - Processing 1 files for step find_features
# 2021-01-09 23:32:42 INFO - Found *.hdf with features for F:/temp\thermo_IRT.ms_data.hdf
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:42 INFO - Processing 1 files for step search_db
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:43 INFO - Performing search on 1,889 query and 40 db entries with m_tol = 30.00 and m_offset = 30.00.
# 2021-01-09 23:32:47 INFO - Compared 156 spectra and found 28 psms.
# 2021-01-09 23:32:47 INFO - Extracting columns for scoring.
# 2021-01-09 23:32:53 INFO - Extracted columns from 28 spectra.
# 2021-01-09 23:32:53 INFO - Saving first_search results to F:/temp\thermo_IRT.ms_data.hdf
# 2021-01-09 23:32:53 INFO - Search of file F:/temp\thermo_IRT.raw complete.
# 2021-01-09 23:32:53 INFO - First search complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:54 INFO - Processing 1 files for step calibrate_hdf
# 2021-01-09 23:32:54 INFO - Scoring using X-Tandem
# 2021-01-09 23:32:54 INFO - Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-01-09 23:32:54 INFO - NumExpr defaulting to 8 threads.
#   0%|                                                                                            | 0/1 [00:11<?, ?it/s]
# 2021-01-09 23:32:54 INFO - Last q_value 0.000 of dataset is smaller than fdr_level 0.010
# 2021-01-09 23:32:54 INFO - 8 target (0 decoy) of 8 PSM. fdr 0.000000 for a cutoff of 18.09
# 2021-01-09 23:32:54 INFO - Not enough data points present. Skipping recalibration.
# 2021-01-09 23:32:54 INFO - Calibration of file F:/temp\thermo_IRT.ms_data.hdf complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:54 INFO - Processing 1 files for step search_db
# 2021-01-09 23:32:54 INFO - Found calibrated m_offset with value 6.68
# 2021-01-09 23:32:54 INFO - Performing search on 1,889 query and 40 db entries with m_tol = 30.00 and m_offset = 6.68.
# 2021-01-09 23:32:54 INFO - Compared 156 spectra and found 28 psms.
# 2021-01-09 23:32:54 INFO - Extracting columns for scoring.
# 2021-01-09 23:32:55 INFO - Extracted columns from 28 spectra.
# 2021-01-09 23:32:55 INFO - Saving second_search results to F:/temp\thermo_IRT.ms_data.hdf
# 2021-01-09 23:32:55 INFO - Search of file F:/temp\thermo_IRT.raw complete.
# 2021-01-09 23:32:55 INFO - Second search complete.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:55 INFO - Processing 1 files for step score_hdf
# 2021-01-09 23:32:55 INFO - Found second search psms for scoring.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:55 INFO - Last q_value 0.000 of dataset is smaller than fdr_level 0.100
# 2021-01-09 23:32:55 INFO - 8 target (0 decoy) of 8 PSM. fdr 0.000000 for a cutoff of 18.09
# 2021-01-09 23:32:55 INFO - The total number of available decoys is lower than the initial set of high scoring targets.
# 2021-01-09 23:32:55 INFO - ML failed. Defaulting to x_tandem score
# 2021-01-09 23:32:55 INFO - There are fewer high scoring targets or decoys than required by 'min_train'.
# 2021-01-09 23:32:55 INFO - Filter df with x_tandem score
# 2021-01-09 23:32:55 INFO - Global FDR on precursor
# 2021-01-09 23:32:55 INFO - Last q_value 0.000 of dataset is smaller than fdr_level 0.010
# 2021-01-09 23:32:55 INFO - 8 target (0 decoy) of 8 PSM. fdr 0.000000 for a cutoff of 18.09
# 2021-01-09 23:32:55 INFO - FDR on peptides complete. For 0.01 FDR found 8 targets and 0 decoys.
# 2021-01-09 23:32:55 INFO - Scoring of file F:/temp\thermo_IRT.ms_data.hdf complete.
# 2021-01-09 23:32:55 INFO - Extracting protein groups.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:55 INFO - A total of 1 proteins with unique PSMs found
# 2021-01-09 23:32:55 INFO - A total of 0 ambigious proteins
# 2021-01-09 23:32:55 INFO - A total of 0 proteins with unique PSMs found
# 2021-01-09 23:32:55 INFO - A total of 0 ambigious proteins
# 2021-01-09 23:32:55 INFO - Global FDR on protein
# 2021-01-09 23:32:55 INFO - Last q_value 0.000 of dataset is smaller than fdr_level 0.010
# 2021-01-09 23:32:55 INFO - 1 target (0 decoy) of 1 PSM. fdr 0.000000 for a cutoff of 41.00
# 2021-01-09 23:32:55 INFO - FDR on proteins complete. For 0.01 FDR found 8 targets and 0 decoys. A total of 1 proteins found.
# 2021-01-09 23:32:55 INFO - Extracting ions
# 2021-01-09 23:32:55 INFO - Extracting ions complete.
# 2021-01-09 23:32:56 INFO - Saving complete.
# 2021-01-09 23:32:56 INFO - Protein groups complete.
# 2021-01-09 23:32:56 INFO - Only 1 dataset present. Skipping alignment.
# 2021-01-09 23:32:56 INFO - Assembling dataframe.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:56 INFO - Assembly complete.
# 2021-01-09 23:32:56 INFO - Complete.
# 2021-01-09 23:32:56 INFO - Starting profile extraction.
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2021-01-09 23:32:56 INFO - LFQ complete.
# 2021-01-09 23:32:56 INFO - Exporting as csv.
# 2021-01-09 23:32:56 INFO - Settings saved to F:\temp\results.yaml
# 2021-01-09 23:32:56 INFO - Analysis complete.

# %% [markdown]
# ## Basic file access
#
# Files can be read via the alphapept.io class and displayed as pandas dataframe

# %%
import alphapept.io

_ = settings['experiment']['file_paths'][0]
base, ext = os.path.splitext(_)

ms_file = alphapept.io.MS_Data_File(base+'.ms_data.hdf')

print(ms_file.read())

df = ms_file.read(dataset_name='protein_fdr')

df.head()
# Out:
# ['Raw', 'corrected_fragment_mzs', 'feature_table', 'features', 'first_search', 'ions', 'peptide_fdr', 'protein_fdr', 'second_search']
#    abs_delta_m_ppm  b-H2O_hits  b-NH3_hits  b_hits  charge  db_idx  decoy  \
# 0         1.881906           0           2       4       2       0  False
# 1        13.398595           0           1       2       2       2  False
# 2         0.245930           4           1       5       2       9  False
# 3        30.018059           2           1       5       2      13  False
# 4        13.148873           5           0       6       2      15  False
#
#    decoys_cum  decoys_cum_protein   delta_m  ...  target  target_cum  \
# 0           0                   0  0.000782  ...    True           6
# 1           0                   0  0.004837  ...    True           8
# 2           0                   0 -0.000090  ...    True           1
# 3           0                   0  0.013741  ...    True           2
# 4           0                   0  0.005780  ...    True           3
#
#    target_cum_protein  target_precursor  target_protein  total_int   x_tandem  \
# 0                   1              True            True   40067735  30.914789
# 1                   1              True            True     635629  18.091496
# 2                   1              True            True   21819864  41.003103
# 3                   1              True            True   12946349  40.650891
# 4                   1              True            True   33162092  36.109841
#
#    y-H2O_hits  y-NH3_hits  y_hits
# 0           3           6       8
# 1           0           0       5
# 2           5           0      12
# 3           9           0      12
# 4           1           2       9
#
# [5 rows x 68 columns]

# %% [markdown]
# ## MS2 Spectrum
#
# Visualize PSMS

# %%
import matplotlib.pyplot as plt

def plot_psms(precursor, ms_file):

    df = ms_file.read(dataset_name='protein_fdr')
    
    ion_dict = {}
    ion_dict[0] = ''
    ion_dict[1] = '-H20'
    ion_dict[2] = '-NH3'

    spectrum = df[df['precursor'] == precursor].iloc[0]
    start = spectrum['ion_idx']
    end = spectrum['n_ions'] + start

    query_data = ms_file.read_DDA_query_data()
    ions = ms_file.read(dataset_name="ions")

    ion = [('b'+str(int(_))).replace('b-','y') for _ in ions.iloc[start:end]['ion_index']]
    losses = [ion_dict[int(_)] for _ in ions.iloc[start:end]['ion_type']]
    ion = [a+b for a,b in zip(ion, losses)]
    ints = ions.iloc[start:end]['ion_int'].astype('int').values
    masses = ions.iloc[start:end]['ion_mass'].astype('float').values
    ion_type = ions.iloc[start:end]['ion_type'].abs().values

    query_idx = spectrum['raw_idx']

    query_indices = query_data["indices_ms2"]
    query_bounds = query_data['bounds']
    query_charges = query_data['charge2']
    query_frags = query_data['mass_list_ms2']
    query_ints = query_data['int_list_ms2']

    query_idx_start = query_indices[query_idx]
    query_idx_end = query_indices[query_idx + 1]
    query_frag = query_frags[query_idx_start:query_idx_end]
    query_int = query_ints[query_idx_start:query_idx_end]

    ax = plt.figure(figsize=(15, 5))

    plt.vlines(query_frag, 0, query_int, "k", label="Query", alpha=0.5)

    plt.vlines(masses, ints, max(query_int)*(1+0.1*ion_type), "k", label="Hits", alpha=0.5, linestyle=':')

    plt.vlines(masses, 0, ints, "r", label="Hits", alpha=0.5)

    for i in range(len(masses)):
        plt.text(masses[i], (1+0.1*ion_type[i])*max(query_int), ion[i])

    figure_title = f"{spectrum['precursor']} - b-hits {spectrum['b_hits']}, y-hits {spectrum['y_hits']}, matched int {spectrum['matched_int_ratio']*100:.2f} %"

    plt.xlabel("Mass")
    plt.ylabel('Intensity')
    plt.ylim([0, (1+0.1*max(ion_type)+0.1)*max(query_int)])
    plt.legend()
    plt.title(figure_title)
    plt.show()
    
    
for index in range(3):
    precursor = df['precursor'].iloc[index]
    print(f" Plotting PSMS for {precursor}")
    plot_psms(precursor, ms_file)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.70it/s]
#  Plotting PSMS for LGGNEQVTR_2
#  Plotting PSMS for YILAGVENSK_2
#  Plotting PSMS for GAGSSEPVTGLDAK_2
